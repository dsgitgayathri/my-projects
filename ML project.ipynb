# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=pd.read_csv('/content/knovist_technologies_conversion_and_sales_data.csv')
a
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# /usr/local/lib/python3.12/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# /usr/local/lib/python3.12/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# ...

# %%
a.head(20)
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# /usr/local/lib/python3.12/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# /usr/local/lib/python3.12/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# ...

# %%
a.tail(20)
# Out:
#                  Name  contact_number                  Contact_email  \
# 27355    Arjun Kapoor      7877303050    arjun.kapoor811@hotmail.com
# 27356    Aditya Kumar      7562448157    aditya.kumar403@hotmail.com
# 27357    Nikhil Patel      8039825189    nikhil.patel299@hotmail.com
# 27358  Kiran Malhotra      6695076399  kiran.malhotra958@outlook.com
# 27359    Sanjay Reddy      6342774525    sanjay.reddy596@example.com
# 27360   Vikram Pillai      8233514194     vikram.pillai734@yahoo.com
# 27361    Varun Chopra      8766023158      varun.chopra144@yahoo.com
# 27362     Kiran Yadav      7048285959       kiran.yadav995@yahoo.com
# 27363   Aditya Shetty      8441599567   aditya.shetty628@outlook.com
# 27364    Rahul Chopra      9207193311      rahul.chopra414@yahoo.com
# 27365     Divya Kumar      9940043493       divya.kumar207@yahoo.com
# 27366   Anjali Chopra      9958508728   anjali.chopra127@example.com
# 27367    Anjali Kumar      6302208813      anjali.kumar727@gmail.com
# ...

# %%
a.shape
# Out:
# (27375, 15)

# %%
a.size
# Out:
# 410625

# %%
a.dtypes
# Out:
# Name                   object
# contact_number          int64
# Contact_email          object
# creation_date          object
# first_call_attempt     object
# lead_status            object
# lead_stage             object
# lead_tag               object
# assigned_to            object
# last_call_date         object
# last_call_time         object
# references            float64
# campaign_name          object
# source_type            object
# source_name            object
# dtype: object

# %%
a.isna().sum()
# Out:
# Name                      0
# contact_number            0
# Contact_email             0
# creation_date             0
# first_call_attempt     6729
# lead_status               0
# lead_stage                0
# lead_tag              11416
# assigned_to               0
# last_call_date         6729
# last_call_time         6729
# references            27375
# campaign_name             0
# source_type               0
# source_name               0
# dtype: int64

# %%
a['creation_date']=pd.to_datetime(a['creation_date'],dayfirst=True)
a['first_call_attempt']=pd.to_datetime(a['first_call_attempt'],dayfirst=True)
a['last_call_date']=pd.to_datetime(a['last_call_date'],dayfirst=True)
a['last_call_time']=pd.to_datetime(a['last_call_time'],dayfirst=True)
# Out:
# /tmp/ipykernel_1270/48637355.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   a['last_call_time']=pd.to_datetime(a['last_call_time'],dayfirst=True)

# %%
a.dtypes
# Out:
# Name                          object
# contact_number                 int64
# Contact_email                 object
# creation_date         datetime64[ns]
# first_call_attempt    datetime64[ns]
# lead_status                   object
# lead_stage                    object
# lead_tag                      object
# assigned_to                   object
# last_call_date        datetime64[ns]
# last_call_time        datetime64[ns]
# references                   float64
# campaign_name                 object
# source_type                   object
# source_name                   object
# dtype: object

# %%
df=a.drop(['Name','Contact_email','source_name','references','contact_number','lead_tag'],axis=1)
df
# Out:
#             creation_date  first_call_attempt               lead_status  \
# 0     2026-02-03 22:31:00                 NaT    PENDING WITH EXECUTIVE
# 1     2026-02-03 21:46:00                 NaT    PENDING WITH EXECUTIVE
# 2     2026-02-03 21:28:00                 NaT    PENDING WITH EXECUTIVE
# 3     2026-02-03 19:59:00                 NaT    PENDING WITH EXECUTIVE
# 4     2026-02-03 19:19:00                 NaT    PENDING WITH EXECUTIVE
# ...                   ...                 ...                       ...
# 27370 2025-06-02 13:14:00 2025-06-02 14:46:00                    CLOSED
# 27371 2025-06-02 13:05:00                 NaT                    CLOSED
# 27372 2025-06-02 12:39:00 2025-06-02 13:13:00                    CLOSED
# 27373 2025-06-02 12:35:00 2025-06-02 13:01:00  RESCHEDULED BY EXECUTIVE
# 27374 2025-06-02 12:35:00 2025-06-02 14:33:00  RESCHEDULED BY EXECUTIVE
#
#                lead_stage assigned_to      last_call_date      last_call_time  \
# ...

# %%
sns.countplot(df['lead_status'])
# Out:
# <Axes: xlabel='count', ylabel='lead_status'>

# %%
sns.countplot(a['campaign_name'])
# Out:
# <Axes: xlabel='count', ylabel='campaign_name'>

# %%
sns.countplot(df['source_type'],color='r')
# Out:
# <Axes: xlabel='count', ylabel='source_type'>

# %%
plt.figure(figsize=(20,2))
sns.barplot(x='lead_status',y='lead_stage',data=df,color='c')
# Out:
# <Axes: xlabel='lead_status', ylabel='lead_stage'>

# %%
sns.countplot(df['lead_stage'])
# Out:
# <Axes: xlabel='count', ylabel='lead_stage'>

# %%
dummy=pd.get_dummies(df[['campaign_name','assigned_to','source_type']],drop_first=True)
dummy
# Out:
#        campaign_name_BA NO STIPEND 28-10-2025  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ...                                       ...
# 27370                                   False
# 27371                                   False
# 27372                                   False
# 27373                                   False
# 27374                                   False
#
#        campaign_name_Business Accounting  campaign_name_Common Ads 21-08-2025  \
# 0                                  False                                False
# 1                                  False                                False
# 2                                  False                                False
# 3                                  False                                False
# ...

# %%
df1=pd.concat([df,dummy],axis=1)
df1
# Out:
#             creation_date  first_call_attempt               lead_status  \
# 0     2026-02-03 22:31:00                 NaT    PENDING WITH EXECUTIVE
# 1     2026-02-03 21:46:00                 NaT    PENDING WITH EXECUTIVE
# 2     2026-02-03 21:28:00                 NaT    PENDING WITH EXECUTIVE
# 3     2026-02-03 19:59:00                 NaT    PENDING WITH EXECUTIVE
# 4     2026-02-03 19:19:00                 NaT    PENDING WITH EXECUTIVE
# ...                   ...                 ...                       ...
# 27370 2025-06-02 13:14:00 2025-06-02 14:46:00                    CLOSED
# 27371 2025-06-02 13:05:00                 NaT                    CLOSED
# 27372 2025-06-02 12:39:00 2025-06-02 13:13:00                    CLOSED
# 27373 2025-06-02 12:35:00 2025-06-02 13:01:00  RESCHEDULED BY EXECUTIVE
# 27374 2025-06-02 12:35:00 2025-06-02 14:33:00  RESCHEDULED BY EXECUTIVE
#
#                lead_stage assigned_to      last_call_date      last_call_time  \
# ...

# %%
df2=df1.drop(['campaign_name','assigned_to','source_type'],axis=1)
df2
# Out:
#             creation_date  first_call_attempt               lead_status  \
# 0     2026-02-03 22:31:00                 NaT    PENDING WITH EXECUTIVE
# 1     2026-02-03 21:46:00                 NaT    PENDING WITH EXECUTIVE
# 2     2026-02-03 21:28:00                 NaT    PENDING WITH EXECUTIVE
# 3     2026-02-03 19:59:00                 NaT    PENDING WITH EXECUTIVE
# 4     2026-02-03 19:19:00                 NaT    PENDING WITH EXECUTIVE
# ...                   ...                 ...                       ...
# 27370 2025-06-02 13:14:00 2025-06-02 14:46:00                    CLOSED
# 27371 2025-06-02 13:05:00                 NaT                    CLOSED
# 27372 2025-06-02 12:39:00 2025-06-02 13:13:00                    CLOSED
# 27373 2025-06-02 12:35:00 2025-06-02 13:01:00  RESCHEDULED BY EXECUTIVE
# 27374 2025-06-02 12:35:00 2025-06-02 14:33:00  RESCHEDULED BY EXECUTIVE
#
#                lead_stage      last_call_date      last_call_time  \
# ...

# %%
df2.dtypes
# Out:
# creation_date                   datetime64[ns]
# first_call_attempt              datetime64[ns]
# lead_status                             object
# lead_stage                              object
# last_call_date                  datetime64[ns]
#                                      ...
# source_type_FILE_UPLOAD                   bool
# source_type_INSTAGRAM                     bool
# source_type_MOVE_LEAD                     bool
# source_type_NEODOVE_DIAL_PAD              bool
# source_type_WALK_IN_LEAD                  bool
# Length: 61, dtype: object

# %%
print(df2['lead_stage'].unique())
# Out:
# ['Prospect' 'LOST' 'Follow Up Required' 'CONVERTED']

# %%
df2['Converted']=np.where(df['lead_stage']=='CONVERTED',1,0)
df2
# Out:
#             creation_date  first_call_attempt               lead_status  \
# 0     2026-02-03 22:31:00                 NaT    PENDING WITH EXECUTIVE
# 1     2026-02-03 21:46:00                 NaT    PENDING WITH EXECUTIVE
# 2     2026-02-03 21:28:00                 NaT    PENDING WITH EXECUTIVE
# 3     2026-02-03 19:59:00                 NaT    PENDING WITH EXECUTIVE
# 4     2026-02-03 19:19:00                 NaT    PENDING WITH EXECUTIVE
# ...                   ...                 ...                       ...
# 27370 2025-06-02 13:14:00 2025-06-02 14:46:00                    CLOSED
# 27371 2025-06-02 13:05:00                 NaT                    CLOSED
# 27372 2025-06-02 12:39:00 2025-06-02 13:13:00                    CLOSED
# 27373 2025-06-02 12:35:00 2025-06-02 13:01:00  RESCHEDULED BY EXECUTIVE
# 27374 2025-06-02 12:35:00 2025-06-02 14:33:00  RESCHEDULED BY EXECUTIVE
#
#                lead_stage      last_call_date      last_call_time  \
# ...

# %%
df2['Converted'].value_counts()
# Out:
# Converted
# 0    26530
# 1      845
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df2['lead_status']=le.fit_transform(df2['lead_status'])
df2
# Out:
#             creation_date  first_call_attempt  lead_status  \
# 0     2026-02-03 22:31:00                 NaT            4
# 1     2026-02-03 21:46:00                 NaT            4
# 2     2026-02-03 21:28:00                 NaT            4
# 3     2026-02-03 19:59:00                 NaT            4
# 4     2026-02-03 19:19:00                 NaT            4
# ...                   ...                 ...          ...
# 27370 2025-06-02 13:14:00 2025-06-02 14:46:00            0
# 27371 2025-06-02 13:05:00                 NaT            0
# 27372 2025-06-02 12:39:00 2025-06-02 13:13:00            0
# 27373 2025-06-02 12:35:00 2025-06-02 13:01:00            5
# 27374 2025-06-02 12:35:00 2025-06-02 14:33:00            5
#
#                lead_stage      last_call_date      last_call_time  \
# 0                Prospect                 NaT                 NaT
# 1                Prospect                 NaT                 NaT
# ...

# %%
df2.dtypes
# Out:
# creation_date                   datetime64[ns]
# first_call_attempt              datetime64[ns]
# lead_status                              int64
# lead_stage                              object
# last_call_date                  datetime64[ns]
#                                      ...
# source_type_INSTAGRAM                     bool
# source_type_MOVE_LEAD                     bool
# source_type_NEODOVE_DIAL_PAD              bool
# source_type_WALK_IN_LEAD                  bool
# Converted                                int64
# Length: 62, dtype: object

# %%
df_final=df2.drop(['lead_stage','last_call_time','first_call_attempt','last_call_date','creation_date'],axis=1)
df_final
# Out:
#        lead_status  campaign_name_BA NO STIPEND 28-10-2025  \
# 0                4                                   False
# 1                4                                   False
# 2                4                                   False
# 3                4                                   False
# 4                4                                   False
# ...            ...                                     ...
# 27370            0                                   False
# 27371            0                                   False
# 27372            0                                   False
# 27373            5                                   False
# 27374            5                                   False
#
#        campaign_name_Business Accounting  campaign_name_Common Ads 21-08-2025  \
# 0                                  False                                False
# 1                                  False                                False
# ...

# %%
x=df_final.iloc[:,:-1].values
x
# Out:
# array([[4, False, False, ..., False, False, False],
#        [4, False, False, ..., False, False, False],
#        [4, False, False, ..., False, False, False],
#        ...,
#        [0, False, True, ..., False, False, False],
#        [5, False, True, ..., False, False, False],
#        [5, False, True, ..., False, False, False]], dtype=object)

# %%
y=df_final.iloc[:,-1].values
y
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)
x_train
# Out:
# array([[0, False, True, ..., False, False, False],
#        [0, False, False, ..., False, False, False],
#        [4, False, False, ..., False, False, False],
#        ...,
#        [0, False, False, ..., False, False, False],
#        [5, False, False, ..., False, False, False],
#        [0, False, False, ..., False, False, False]], dtype=object)

# %%
x_test
# Out:
# array([[4, False, False, ..., False, False, False],
#        [0, False, False, ..., False, False, False],
#        [2, False, False, ..., True, False, False],
#        ...,
#        [4, False, False, ..., False, False, False],
#        [5, False, False, ..., False, False, False],
#        [0, False, False, ..., True, False, False]], dtype=object)

# %%
y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
x_train['year']=x_train['']

# %%
from sklearn.preprocessing import StandardScaler
model=StandardScaler()
model.fit(x_train)
x_train=model.fit_transform(x_train)
x_test=model.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-1.0099319 , -0.05165869,  3.0408977 , ..., -0.3423266 ,
#         -0.00722422, -0.02798951],
#        [-1.0099319 , -0.05165869, -0.32885026, ..., -0.3423266 ,
#         -0.00722422, -0.02798951],
#        [ 1.00033273, -0.05165869, -0.32885026, ..., -0.3423266 ,
#         -0.00722422, -0.02798951],
#        ...,
#        [-1.0099319 , -0.05165869, -0.32885026, ..., -0.3423266 ,
#         -0.00722422, -0.02798951],
#        [ 1.50289889, -0.05165869, -0.32885026, ..., -0.3423266 ,
#         -0.00722422, -0.02798951],
#        [-1.0099319 , -0.05165869, -0.32885026, ..., -0.3423266 ,
#         -0.00722422, -0.02798951]])

# %%
x_test
# Out:
# array([[ 1.03071955, -0.05743095, -0.3312324 , ..., -0.33708622,
#          0.        , -0.02703855],
#        [-0.99531998, -0.05743095, -0.3312324 , ..., -0.33708622,
#          0.        , -0.02703855],
#        [ 0.01769979, -0.05743095, -0.3312324 , ...,  2.96660007,
#          0.        , -0.02703855],
#        ...,
#        [ 1.03071955, -0.05743095, -0.3312324 , ..., -0.33708622,
#          0.        , -0.02703855],
#        [ 1.53722943, -0.05743095, -0.3312324 , ..., -0.33708622,
#          0.        , -0.02703855],
#        [-0.99531998, -0.05743095, -0.3312324 , ...,  2.96660007,
#          0.        , -0.02703855]])

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
sv=SVC()
dt=DecisionTreeClassifier()
rf=RandomForestClassifier()
lst_model=[sv,dt,rf]

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
for i in lst_model:
  print(i)
  i.fit(x_train,y_train)
  y_pred=i.predict(x_test)
  print(y_pred)
  print(confusion_matrix(y_pred,y_test))
  print(accuracy_score(y_pred,y_test))
  print(classification_report(y_pred,y_test))
# Out:
# SVC()
# [0 0 0 ... 0 0 0]
# [[7863   98]
#  [  90  162]]
# 0.977109460611226
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7961
#            1       0.62      0.64      0.63       252
#
#     accuracy                           0.98      8213
#    macro avg       0.81      0.82      0.81      8213
# weighted avg       0.98      0.98      0.98      8213
#
# DecisionTreeClassifier()
# [0 0 0 ... 0 0 0]
# [[7862   98]
#  [  91  162]]
# 0.9769877024229879
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7960
#            1       0.62      0.64      0.63       253
#
#     accuracy                           0.98      8213
#    macro avg       0.81      0.81      0.81      8213
# weighted avg       0.98      0.98      0.98      8213
#
# RandomForestClassifier()
# [0 0 0 ... 0 0 0]
# [[7863   98]
#  [  90  162]]
# 0.977109460611226
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print(confusion_matrix(y_pred,y_test))
print(accuracy_score(y_pred,y_test))
print(classification_report(y_pred,y_test))
# Out:
# [[7862   98]
#  [  91  162]]
# 0.9769877024229879
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7960
#            1       0.62      0.64      0.63       253
#
#     accuracy                           0.98      8213
#    macro avg       0.81      0.81      0.81      8213
# weighted avg       0.98      0.98      0.98      8213
